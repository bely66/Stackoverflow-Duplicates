# %% [markdown]
# # Find duplicate questions on StackOverflow by their embeddings

# %% [markdown]
# ### Data
#
# The following cell will download all data required.

# %%
import google.colab



! wget https://raw.githubusercontent.com/hse-aml/natural-language-processing/master/setup_google_colab.py -O setup_google_colab.py
from setup_google_colab import setup_week3 as setup_req



setup_req()
# Out:
# --2020-11-04 09:04:12--  https://raw.githubusercontent.com/hse-aml/natural-language-processing/master/setup_google_colab.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1939 (1.9K) [text/plain]
# Saving to: ‘setup_google_colab.py’
#
# setup_google_colab. 100%[===================>]   1.89K  --.-KB/s    in 0s
#
# 2020-11-04 09:04:12 (39.8 MB/s) - ‘setup_google_colab.py’ saved [1939/1939]

# %%
from common.download_utils import download_week3_resources

download_week3_resources()
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=119127793.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=535543630.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=46408910.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5333.0), HTML(value='')))
# Downloading GoogleNews-vectors-negative300.bin.gz (1.5G) for you, it will take a while...
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1647046227.0), HTML(value='')))

# %% [markdown]
# ## Word embedding
#
# To solve the problem, you will use two different models of embeddings:
#
#  - [Pre-trained word vectors](https://code.google.com/archive/p/word2vec/) from Google which were trained on a part of Google News dataset (about 100 billion words). The model contains 300-dimensional vectors for 3 million words and phrases. `GoogleNews-vectors-negative300.bin.gz`.
#  - Representations using StarSpace on StackOverflow data sample. You will need to train them from scratch.

# %% [markdown]
# It's always easier to start with pre-trained embeddings. Unpack the pre-trained Goggle's vectors and upload them using the function [KeyedVectors.load_word2vec_format](https://radimrehurek.com/gensim/models/keyedvectors.html) from gensim library with the parameter *binary=True*. If the size of the embeddings is larger than the avaliable memory, you could load only a part of the embeddings by defining the parameter *limit* (recommended: 500000).

# %%
# !gunzip GoogleNews-vectors-negative300.bin.gz
# Out:
# gzip: GoogleNews-vectors-negative300.bin.gz: No such file or directory

# %%
import gensim

# %%
from gensim.test.utils import datapath
from gensim.models import KeyedVectors
wv_embeddings = KeyedVectors.load_word2vec_format(("GoogleNews-vectors-negative300.bin"), binary=True)

# %% [markdown]
# ### How to work with Google's word2vec embeddings?
#
# Once you have loaded the representations, make sure you can access them. First, you can check if the loaded embeddings contain a word:
#
#     'word' in wv_embeddings
#
# Second, to get the corresponding embedding you can use the square brackets:
#
#     wv_embeddings['word']
#
# ### Checking that the embeddings are correct
#
# To prevent any errors during the first stage, we can check that the loaded embeddings are correct. You can call the function *check_embeddings*, implemented below, which runs 3 tests:
# 1. Find the most similar word for provided "positive" and "negative" words.
# 2. Find which word from the given list doesn’t go with the others.
# 3. Find the most similar word for the provided one.
#
# In the right case the function will return the string *These embeddings look good*. Othervise, you need to validate the previous steps.

# %%
def check_embeddings(embeddings):
    error_text = "Something wrong with your embeddings ('%s test isn't correct)."
    most_similar = embeddings.most_similar(positive=['woman', 'king'], negative=['man'])
    if len(most_similar) < 1 or most_similar[0][0] != 'queen':
        return error_text % "Most similar"

    doesnt_match = embeddings.doesnt_match(['breakfast', 'cereal', 'dinner', 'lunch'])
    if doesnt_match != 'cereal':
        return error_text % "Doesn't match"
    
    most_similar_to_given = embeddings.most_similar_to_given('music', ['water', 'sound', 'backpack', 'mouse'])
    if most_similar_to_given != 'sound':
        return error_text % "Most similar to given"
    
    return "These embeddings look good."

# %%
print(check_embeddings(wv_embeddings))
# Out:
# These embeddings look good.
# /usr/local/lib/python3.6/dist-packages/gensim/models/keyedvectors.py:877: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)

# %% [markdown]
# ## From word to text embeddings
#
#  Usually, we have word-based embeddings, but for the task we need to create a representation for the whole question. It could be done in different ways. In our case we will use a **mean** of all word vectors in the question. Now you need to implement the function *question_to_vec*, which calculates the question representation described above. This function should work with the input text as is without any preprocessing.
#
# Note that there could be words without the corresponding embeddings. In this case, you can just skip these words and don't take them into account during calculating the result. If the question doesn't contain any known word with embedding, the function should return a zero vector.

# %%
import numpy as np

# %%
import numpy as np
def question_to_vec(question, embeddings, dim=300):
    """
        question: a string
        embeddings: dict where the key is a word and a value is its' embedding
        dim: size of the representation

        result: vector representation for the question
    """

    words_embedding = [embeddings[word] for word in question.split() if word in embeddings]
    if not words_embedding:
        return np.zeros(dim)
    words_embedding = np.array(words_embedding)
    return words_embedding.mean(axis=0)

# %% [markdown]
# To check the basic correctness of your implementation, run the function *question_to_vec_tests*.

# %%
def question_to_vec_tests():
    if (np.zeros(300) != question_to_vec('', wv_embeddings)).any():
        return "You need to return zero vector for empty question."
    if (np.zeros(300) != question_to_vec('thereisnosuchword', wv_embeddings)).any():
        return "You need to return zero vector for the question, which consists only unknown words."
    if (wv_embeddings['word'] != question_to_vec('word', wv_embeddings)).any():
        return "You need to check the corectness of your function."
    if ((wv_embeddings['I'] + wv_embeddings['am']) / 2 != question_to_vec('I am', wv_embeddings)).any():
        return "Your function should calculate a mean of word vectors."
    if (wv_embeddings['word'] != question_to_vec('thereisnosuchword word', wv_embeddings)).any():
        return "You should not consider words which embeddings are unknown."
    return "Basic tests are passed."

# %%
print(question_to_vec_tests())
# Out:
# Basic tests are passed.

# %% [markdown]
# You can submit embeddings for the questions from the file *test_embeddings.tsv* to earn the points. In this task you don't need to transform the text of a question somehow.

# %%
import nltk
nltk.download('stopwords')
from util import array_to_string
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# Now we have a method to create a representation of any sentence and we are ready for the first evaluation. So, let's check how well our solution (Google's vectors + *question_to_vec*) will work.
#
# ## Evaluation of text similarity
#
# We can imagine that if we use good embeddings, the cosine similarity between the duplicate sentences should be less than for the random ones. Overall, for each pair of duplicate sentences we can generate *R* random negative examples and find out the position of the correct duplicate.
#
# For example, we have the question *"Exceptions What really happens"* and we are sure that another question *"How does the catch keyword determine the type of exception that was thrown"* is a duplicate. But our model doesn't know it and tries to find out the best option also among questions like *"How Can I Make These Links Rotate in PHP"*, *"NSLog array description not memory address"* and *"PECL_HTTP not recognised php ubuntu"*. The goal of the model is to rank all these 4 questions (1 *positive* and *R* = 3 *negative*) in the way that the correct one is in the first place.
#
# However, it is unnatural to count on that the best candidate will be always in the first place. So let us consider the place of the best candidate in the sorted list of candidates and formulate a metric based on it. We can fix some *K* — a reasonalble number of top-ranked elements and *N* — a number of queries (size of the sample).
#
# ### Hits@K
#
# The first simple metric will be a number of correct hits for some *K*:
# $$ \text{Hits@K} = \frac{1}{N}\sum_{i=1}^N \, [dup_i \in topK(q_i)]$$
#
# where $q_i$ is the i-th query, $dup_i$ is its duplicate, $topK(q_i)$ is the top K elements of the ranked sentences provided by our model and the operation $[dup_i \in topK(q_i)]$ equals 1 if the condition is true and 0 otherwise (more details about this operation could be found [here](https://en.wikipedia.org/wiki/Iverson_bracket)).
#
#
# ### DCG@K
# The second one is a simplified [DCG metric](https://en.wikipedia.org/wiki/Discounted_cumulative_gain):
#
# $$ \text{DCG@K} = \frac{1}{N} \sum_{i=1}^N\frac{1}{\log_2(1+rank_{dup_i})}\cdot[rank_{dup_i} \le K] $$
#
# where $rank_{dup_i}$ is a position of the duplicate in the sorted list of the nearest sentences for the query $q_i$. According to this metric, the model gets a higher reward for a higher position of the correct answer. If the answer does not appear in topK at all, the reward is zero.

# %% [markdown]
# ### Evaluation examples
#
# Let's calculate the described metrics for the toy example introduced above. In this case $N$ = 1 and the correct candidate for $q_1$ is *"How does the catch keyword determine the type of exception that was thrown"*. Consider the following ranking of the candidates:
# 1. *"How Can I Make These Links Rotate in PHP"*
# 2. *"How does the catch keyword determine the type of exception that was thrown"*
# 3. *"NSLog array description not memory address"*
# 4. *"PECL_HTTP not recognised php ubuntu"*
#
# Using the ranking above, calculate *Hits@K* metric for *K = 1, 2, 4*:
#
# - [K = 1] $\text{Hits@1} = \frac{1}{1}\sum_{i=1}^1 \, [dup_i \in top1(q_i)] = [dup_1 \in top1(q_1)] = 0$ because the correct answer doesn't appear in the *top1* list.
# - [K = 2] $\text{Hits@2} = \frac{1}{1}\sum_{i=1}^1 \, [dup_i \in top2(q_i)] = [dup_1 \in top2(q_1)] = 1$ because $rank_{dup_1} = 2$.
# - [K = 4] $\text{Hits@4} = \frac{1}{1}\sum_{i=1}^1 \, [dup_i \in top4(q_i)] = [dup_1 \in top4(q_1)] = 1$
#
# Using the ranking above, calculate *DCG@K* metric for *K = 1, 2, 4*:
#
# - [K = 1] $\text{DCG@1} = \frac{1}{1} \sum_{i=1}^1\frac{1}{\log_2(1+rank_{dup_i})}\cdot[rank_{dup_i} \le 1] = \frac{1}{\log_2(1+rank_{dup_i})}\cdot[rank_{dup_i} \le 1] = 0$ because the correct answer doesn't appear in the top1 list.
# - [K = 2] $\text{DCG@2} = \frac{1}{1} \sum_{i=1}^1\frac{1}{\log_2(1+rank_{dup_i})}\cdot[rank_{dup_i} \le 2] = \frac{1}{\log_2{3}}$, because $rank_{dup_1} = 2$.
# - [K = 4] $\text{DCG@4} = \frac{1}{1} \sum_{i=1}^1\frac{1}{\log_2(1+rank_{dup_i})}\cdot[rank_{dup_i} \le 4] = \frac{1}{\log_2{3}}$.

# %%
def hits_count(dup_ranks, k):
    """
        dup_ranks: list of duplicates' ranks; one rank per question; 
                   length is a number of questions which we are looking for duplicates; 
                   rank is a number from 1 to len(candidates of the question); 
                   e.g. [2, 3] means that the first duplicate has the rank 2, the second one — 3.
        k: number of top-ranked elements (k in Hits@k metric)

        result: return Hits@k value for current ranking
    """
    return (np.array(dup_ranks)<=k).mean()

# %% [markdown]
# Test your code on the tiny examples:

# %%
def test_hits():
    # *Evaluation example*
    # answers — dup_i
    answers = ["How does the catch keyword determine the type of exception that was thrown"]
    
    # candidates_ranking — the ranked sentences provided by our model
    candidates_ranking = [["How Can I Make These Links Rotate in PHP", 
                           "How does the catch keyword determine the type of exception that was thrown",
                           "NSLog array description not memory address",
                           "PECL_HTTP not recognised php ubuntu"]]
    # dup_ranks — position of the dup_i in the list of ranks +1
    dup_ranks = [candidates_ranking[i].index(answers[i]) + 1 for i in range(len(answers))]
    
    # correct_answers — the expected values of the result for each k from 1 to 4
    correct_answers = [0, 1, 1, 1]
    for k, correct in enumerate(correct_answers, 1):
        if not np.isclose(hits_count(dup_ranks, k), correct):
            return "Check the function."
    
    # Other tests
    answers = ["How does the catch keyword determine the type of exception that was thrown", 
               "Convert Google results object (pure js) to Python object"]
    
    # The first test: both duplicates on the first position in ranked list
    candidates_ranking = [["How does the catch keyword determine the type of exception that was thrown",
                           "How Can I Make These Links Rotate in PHP"], 
                          ["Convert Google results object (pure js) to Python object",
                           "WPF- How to update the changes in list item of a list"]]
    dup_ranks = [candidates_ranking[i].index(answers[i]) + 1 for i in range(len(answers))]
    correct_answers = [1, 1]
    for k, correct in enumerate(correct_answers, 1):
        if not np.isclose(hits_count(dup_ranks, k), correct):
            return "Check the function (test: both duplicates on the first position in ranked list)."
        
    # The second test: one candidate on the first position, another — on the second
    candidates_ranking = [["How Can I Make These Links Rotate in PHP", 
                           "How does the catch keyword determine the type of exception that was thrown"], 
                          ["Convert Google results object (pure js) to Python object",
                           "WPF- How to update the changes in list item of a list"]]
    dup_ranks = [candidates_ranking[i].index(answers[i]) + 1 for i in range(len(answers))]
    correct_answers = [0.5, 1]
    for k, correct in enumerate(correct_answers, 1):
        if not np.isclose(hits_count(dup_ranks, k), correct):
            return "Check the function (test: one candidate on the first position, another — on the second)."

    # The third test: both candidates on the second position
    candidates_ranking = [["How Can I Make These Links Rotate in PHP", 
                           "How does the catch keyword determine the type of exception that was thrown"], 
                          ["WPF- How to update the changes in list item of a list",
                           "Convert Google results object (pure js) to Python object"]]
    dup_ranks = [candidates_ranking[i].index(answers[i]) + 1 for i in range(len(answers))]
    correct_answers = [0, 1]
    for k, correct in enumerate(correct_answers, 1):
        if not np.isclose(hits_count(dup_ranks, k), correct):
            return "Check the function (test: both candidates on the second position)."

    return "Basic test are passed."

# %%
print(test_hits())
# Out:
# Basic test are passed.

# %%
def dcg_score(dup_ranks, k):
    """
        dup_ranks: list of duplicates' ranks; one rank per question; 
                   length is a number of questions which we are looking for duplicates; 
                   rank is a number from 1 to len(candidates of the question); 
                   e.g. [2, 3] means that the first duplicate has the rank 2, the second one — 3.
        k: number of top-ranked elements (k in DCG@k metric)

        result: return DCG@k value for current ranking
    """

    dup_ranks = np.array(dup_ranks)
    return ((dup_ranks <= k)/(np.log2(1+dup_ranks))).mean()

# %%
def test_dcg():
    # *Evaluation example*
    # answers — dup_i
    answers = ["How does the catch keyword determine the type of exception that was thrown"]
    
    # candidates_ranking — the ranked sentences provided by our model
    candidates_ranking = [["How Can I Make These Links Rotate in PHP", 
                           "How does the catch keyword determine the type of exception that was thrown",
                           "NSLog array description not memory address",
                           "PECL_HTTP not recognised php ubuntu"]]
    # dup_ranks — position of the dup_i in the list of ranks +1
    dup_ranks = [candidates_ranking[i].index(answers[i]) + 1 for i in range(len(answers))]
    
    # correct_answers — the expected values of the result for each k from 1 to 4
    correct_answers = [0, 1 / (np.log2(3)), 1 / (np.log2(3)), 1 / (np.log2(3))]
    for k, correct in enumerate(correct_answers, 1):
        if not np.isclose(dcg_score(dup_ranks, k), correct):
            return "Check the function."
    
    # Other tests
    answers = ["How does the catch keyword determine the type of exception that was thrown", 
               "Convert Google results object (pure js) to Python object"]

    # The first test: both duplicates on the first position in ranked list
    candidates_ranking = [["How does the catch keyword determine the type of exception that was thrown",
                           "How Can I Make These Links Rotate in PHP"], 
                          ["Convert Google results object (pure js) to Python object",
                           "WPF- How to update the changes in list item of a list"]]
    dup_ranks = [candidates_ranking[i].index(answers[i]) + 1 for i in range(len(answers))]
    correct_answers = [1, 1]
    for k, correct in enumerate(correct_answers, 1):
        if not np.isclose(dcg_score(dup_ranks, k), correct):
            return "Check the function (test: both duplicates on the first position in ranked list)."
        
    # The second test: one candidate on the first position, another — on the second
    candidates_ranking = [["How Can I Make These Links Rotate in PHP", 
                           "How does the catch keyword determine the type of exception that was thrown"], 
                          ["Convert Google results object (pure js) to Python object",
                           "WPF- How to update the changes in list item of a list"]]
    dup_ranks = [candidates_ranking[i].index(answers[i]) + 1 for i in range(len(answers))]
    correct_answers = [0.5, (1 + (1 / (np.log2(3)))) / 2]
    for k, correct in enumerate(correct_answers, 1):
        if not np.isclose(dcg_score(dup_ranks, k), correct):
            return "Check the function (test: one candidate on the first position, another — on the second)."
        
    # The third test: both candidates on the second position
    candidates_ranking = [["How Can I Make These Links Rotate in PHP",
                           "How does the catch keyword determine the type of exception that was thrown"], 
                          ["WPF- How to update the changes in list item of a list",
                           "Convert Google results object (pure js) to Python object"]]
    dup_ranks = [candidates_ranking[i].index(answers[i]) + 1 for i in range(len(answers))]
    correct_answers = [0, 1 / (np.log2(3))]
    for k, correct in enumerate(correct_answers, 1):
        if not np.isclose(dcg_score(dup_ranks, k), correct):
            return "Check the function (test: both candidates on the second position)."

    return "Basic test are passed."

# %%
print(test_dcg())
# Out:
# Basic test are passed.

# %% [markdown]
# ## pre-trained embeddings

# %% [markdown]
# We will work with predefined train, validation and test corpora. All the files are tab-separated, but have a different format:
#  - *train* corpus contains similar sentences at the same row.
#  - *validation* corpus contains the following columns: *question*, *similar question*, *negative example 1*, *negative example 2*, ...
#  - *test* corpus contains the following columns: *question*, *example 1*, *example 2*, ...
#
# Validation corpus will be used for the intermediate validation of models. The test data will be necessary for submitting the quality of your model in the system.

# %% [markdown]
# Now you should read *validation* corpus, located at `data/validation.tsv`. You will use it later to evaluate current solution.

# %%
def read_corpus(filename):
    data = []
    for line in open(filename, encoding='utf-8'):
        data.append(line.strip().split('\t'))
    return data

# %%
validation = read_corpus("data/validation.tsv")

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# We will use cosine distance to rank candidate questions which you need to implement in the function *rank_candidates*. The function should return a sorted list of pairs *(initial position in candidates list, candidate)*. Index of some pair corresponds to its rank (the first is the best). For example, if the list of candidates was *[a, b, c]* and the most similar is *c*, then *a* and *b*, the function should return a list *[(2, c), (0, a), (1, b)]*.
#
# Pay attention, if you use the function *cosine_similarity* from *sklearn.metrics.pairwise* to calculate similarity because it works in a different way: most similar objects has greatest similarity. It's preferable to use a vectorized version of *cosine_similarity* function. Try to compute similarity at once and not use list comprehension. It should speed up your computations significantly.

# %%
def rank_candidates(question, candidates, embeddings, dim=300):
    """
        question: a string
        candidates: a list of strings (candidates) which we want to rank
        embeddings: some embeddings
        dim: dimension of the current embeddings
        
        result: a list of pairs (initial position in the list, question)
    """
    
    question_embedding = question_to_vec(question, embeddings, dim=dim)[np.newaxis,:]
    candidates_embedding = np.array([question_to_vec(candidate, embeddings, dim=dim) for candidate in candidates])
    similarities = cosine_similarity(question_embedding, candidates_embedding)[0]
    similarities = sorted([(similarity, i) for i, similarity in enumerate(similarities)], reverse=True)
    return [(similarity[1], candidates[similarity[1]]) for similarity in similarities]

# %% [markdown]
# Test your code on the tiny examples:

# %%
def test_rank_candidates():
    questions = ['converting string to list', 'Sending array via Ajax fails']
    candidates = [['Convert Google results object (pure js) to Python object', 
                   'C# create cookie from string and send it',
                   'How to use jQuery AJAX for an outside domain?'], 
                  ['Getting all list items of an unordered list in PHP', 
                   'WPF- How to update the changes in list item of a list', 
                   'select2 not displaying search results']]
    results = [[(1, 'C# create cookie from string and send it'), 
                (0, 'Convert Google results object (pure js) to Python object'), 
                (2, 'How to use jQuery AJAX for an outside domain?')],
               [(0, 'Getting all list items of an unordered list in PHP'), 
                (2, 'select2 not displaying search results'), 
                (1, 'WPF- How to update the changes in list item of a list')]]
    for question, q_candidates, result in zip(questions, candidates, results):
        ranks = rank_candidates(question, q_candidates, wv_embeddings, 300)
        if not np.all(ranks == result):
            return "Check the function."
    return "Basic tests are passed."

# %%
print(test_rank_candidates())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-83fc63df2016> in <module>()
# ----> 1 print(test_rank_candidates())
#
# <ipython-input-16-e290c0a9c7b2> in test_rank_candidates()
#      14                 (1, 'WPF- How to update the changes in list item of a list')]]
#      15     for question, q_candidates, result in zip(questions, candidates, results):
# ---> 16         ranks = rank_candidates(question, q_candidates, wv_embeddings, 300)
#      17         if not np.all(ranks == result):
#      18             return "Check the function."
#
# NameError: name 'wv_embeddings' is not defined

# %% [markdown]
# Now we can test the quality of the current approach. Run the next two cells to get the results. Pay attention that calculation of similarity between vectors takes time and this calculation is computed approximately in 10 minutes.

# %%
wv_ranking = []
for line in validation:
    q, *ex = line
    ranks = rank_candidates(q, ex, wv_embeddings)
    wv_ranking.append([r[0] for r in ranks].index(0) + 1)

# %%
for k in [1, 5, 10, 100, 500, 1000]:
    print("DCG@%4d: %.3f | Hits@%4d: %.3f" % (k, dcg_score(wv_ranking, k), k, hits_count(wv_ranking, k)))
# Out:
# DCG@   1: 0.207 | Hits@   1: 0.207
# DCG@   5: 0.265 | Hits@   5: 0.316
# DCG@  10: 0.282 | Hits@  10: 0.367
# DCG@ 100: 0.320 | Hits@ 100: 0.557
# DCG@ 500: 0.353 | Hits@ 500: 0.814
# DCG@1000: 0.372 | Hits@1000: 1.000

# %% [markdown]
# If you did all the steps correctly, you should be frustrated by the received results. Let's try to understand why the quality is so low. First of all, when you work with some data it is necessary to have an idea how the data looks like. Print several questions from the data:

# %%
for line in validation[:3]:
    q, *examples = line
    print(q, *examples[:3])
# Out:
# How to print a binary heap tree without recursion? How do you best convert a recursive function to an iterative one? How can i use ng-model with directive in angular js flash: drawing and erasing
# How to start PhoneStateListener programmatically? PhoneStateListener and service Java cast object[] to model WCF and What does this mean?
# jQuery: Show a div2 when mousenter over div1 is over when hover on div1 depenting on if it is on div2 or not it should act differently How to run selenium in google app engine/cloud? Python Comparing two lists of strings for similarities

# %% [markdown]
# As you can see, we deal with the raw data. It means that we have many punctuation marks, special characters and unlowercased letters. In our case, it could lead to the situation where we can't find some embeddings, e.g. for the word "grid?".
#
# To solve this problem you should use the functions *text_prepare* from the previous assignments to prepare the data.

# %%
from util import text_prepare

# %% [markdown]
# Now transform all the questions from the validation set:

# %%
prepared_validation = []
for line in validation:
    prepared_validation.append(text_prepare(l) for l in line)

# %%
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ['Possible problem with ComponentOne controls in vb6', 'VB 6 crash on exit', 'Settings File as Dictionary with Serialization', 'How does QueryFrame work?', 'Syntax error "syntax error, unexpected end-of-input, expecting keyword_end (SyntaxError)"', 'Linked List sentinel node to avoid reassigning pointer to first node', 'Julia: packaging things into modules vs include()-ing them', 'TeeChart Lite FMX (RAD Studio XE8) anti-aliasing artifacts', 'Node/Express: concurrency issues when using session to store state', 'Toggle div on click or touch and hide on click/touch outside', 'active model serializers rails json doesnt work inside another json object', 'Error using progress bar: Max must be a positive integer', 'Does the GD library use a lot of memory?', 'Big Oh Notation - formal definition', 'Good IM/Chat solution for pasting code', 'Deploying a node js app that uses mongo db on aws', 'PHP REGEX: Problem with Smiley `:)` and `:))`', 'Embedding plots in kivy', 'Fast in time Java int[] compression tool', 'Are there security concerns exposing the clientId and tenant in client side code when using adal/adal-angular.js', 'Cant set text in TextView - android', 'insert into timestamp oracle column from java', "Why doesn't WCFTestclient understand standard EF objects but understands STE objects", 'Claims-based Sharepoint site and Apache CXF STSClient communication', 'How to keep data when run test in rails', 'Drawing a transparent shape in libGDX as an Actor?', 'CakePHP display custom fields from array', 'Callback execution sequence in Javascript, Retrieving from IndexeddB', 'Comments à la "click to appear" with jQuery', 'How to send in-app announcements to people using my iOS app?', 'How can I insert and delete value in a database in derby in JSP?', 'How to read only from file descriptors that have changed', 'referencing local dart libraries', 'bash- Redirection inside quotes after ssh', 'Java: classes with instance of each other', 'Running remote_console of an erlang release via ssh works weird', 'Creating a result set (using a select statement ) within a loop', 'Android GUI update at runtime', 'Do we have Reminders in windows 8', 'Error while reading CSV with VBA', 'PostgreSQL: `unnest` an array and then `array_agg` it back', 'How to add couchdb server into docker creation file', 'Laravel File Upload Validation', 'Is ++ operator more expensive than | operator in Erlang?', 'Codeigniter: Using PDO instead of mysql', "Still get error Unable to load dynamic library '/home/max/mongo/bin/mongo'", 'How do I find intersection of 3 arrays, while ignoring empty arrays?', 'Laravel Blade - custom method for html block?', 'SharedPreferences - OnSharedPreferenceChangeListener', 'Inserting a checkbox via jQuery stops the form to submit on webkit', 'Properties in partial class not appearing in Data Sources window!', 'Parsing and converting Datetime format from csv file to mysql in Java', 'Data Driven Test on Visual Studio using a complex serialized object', 'adding native php function to ctags for vim', 'How do I reconnect a client when server is down in Java?', 'how to append strings to textview', 'Compare two List<string> and print the duplicates', 'How to add an Outlook VSTO 2010 context menu within the message?', 'For matlab, I have an array with 5 sentences, and I need to find the number of special characters in each sentence', 'mvc 4 asp.net - export data to .csv from a local .xls file', 'test data builder for java', 'OpenGL Scene to Screen Transformation', 'Need a case insensitive collation where ss != ß', 'IIS Rewrite not working (but redirection does)', 'http c++ library?', 'hadoop nodes with Linux + windows', 'Change origin of image coordinate system to bottom left instead of default top left', 'Android Bluetooth OBDII communication', 'I have a Java Spring project where Autosys runs on a Unix server. How do I make it work in a Windows environment locally', 'Select data from SQLite into ListArrays', 'How to install R on RedHat', 'Nutch does  ...
# ['Using GPGME in Debian for C++ Application', 'Unexpected Struct while using GPGME in C++ Application', 'How to bundle Angular 2 component css?', 'How can I append this php link to the end of the excerpt?', 'Generating a very large random number and storing it in string buffer and writing it to file', 'Requiring unknown module "buffer" in react-native-route-flux', 'position absolute.. anyway to stop this elements moving?', 'In Java, how I count the size of the download of a webpage during the download?', 'Conflicting setter definitions for property \\"currency\\": javax.money.MonetaryAmountFactory', 'How can I use an alert dialog with Python in linux?', 'Matplotlib contour plot with intersecting contour lines', 'How to bind IN-clause values in a CQL 3 prepared statement?', 'problem with trying to create ssms add-in', 'Listen to all requests from UIWebView', 'CSS Sliding Underline does not work in Safari?', 'jQuery FancyBox stopping ASP.NET Logout link from working', 'Android - Parse PHP json_encode to Java', 'For loop in Oracle SQL', 'Reload Fragment', 'Array_agg in postgres selectively quotes', 'How to obtain all the cookies from same domain', 'How to use class_eval for multi attributes value', 'Aborted upload causes Sails js/Skipper to crash', 'Absolute beginners guide to working with audio in C/C++?', 'Find all matches in a varchar2()', 'Could not delete applet', 'How to show month, year using rich:calendar?', "Can someone help explain why I get this 'Value is not what was expected' error with Javascript?", 'Java Generics, Create an instance of Class<T>', 'Navigating to an aurelia route with a parameter and in a new browser tab', 'VS2017 RC update database from local/azure', 'Calculations over Multiple Rows SQL Server', 'Java 8 Optional', 'What are the possible Amazon MWS Report column headers after last localization?', 'Golang Group by key + merge array values', 'Using MPI with parallel HDF5', 'EF6 CodeFirst One to Many MySQL a foreign key constraint fails', 'Specify File upload path', 'Android device not showing up in DDMS', 'Is OCamlexample app on iPad usable?', '.NET NetworkStream.EndWrite() bytes written', 'Is it possible to copy class fields with unsafe', 'Get Azure premium storage account properties', 'ImportError: No module named psycopg2 when running python script from Java', 'VBA adding columns to array as loop occurs', 'Apple\'s App Search API Validation Tool - "Error cannot fetch app site association"', 'Detecting language using Stanford NLP', 'libGL error: unable to load driver: i965_dri.so in CentOS system', 'Install MVC on 2.0.NET Server with IIS6 without Admin Rights', 'tracking if a result has already been computed using hash table', 'how to get QR code type', 'Does iPhone OS 3.0.1 ruin your development phone?', "dynamic_cast an interface from a shared library which was loaded by lt_dlopen(libtool) doesn't work", 'Render MS Symbol font characters in html5', 'Finding a control in TemplatedWizardStep', 'Not enough permissions to install service', 'Tying to not ignore subfolders with files inside', 'submitting a parameterized hudson build via the REST API', 'Python: Return list result problem in a function', 'Why would you want trailing spaces in an HTML document?', 'Change text from uppercase to lowercase jQuery', 'Money Data Type Precision - SQL Server (SSMS)', 'How to break when found the item?', 'What does "powerful" mean, when discussing programming languages?', "the var doesn't become global but remains local", "About the annotation @interface and it's implementation", 'How do we represent negative numbers in prolog', 'Create an array images to make movement in C#', 'how to reload the template when working with enlive without restar', 'How do I get formatted_phone_number from this link using Javascript?', 'Passing parameters to custom UITableViewCell', 'preg_match to Javascript function', 'TreeView - OnSelectedNodeChanged not firing for Programmatically Added Nodes', 'Retrofit, how to parse JSON objects  ...
# ['No Grails View in IntelliJ', 'Grails View disappeared in IntelliJ, how to get it back?', 'File.createNewFile() method throws exception in Android M', "syntax error, unexpected 'NVPToArray' (T_STRING), expecting function (T_FUNCTION)", 'Passing context to Handler', 'Change custom attribute values', 'How to authenticate users from database with an authentication provider?', "Azure project does not run locally - can't find assemblies", 'Looped charts and worksheets as sheets unsuccessfully. Exactly what caused the errors?', 'Invoke javaScript function on click event of ASP.NET button', 'Running IBM Rhapsody animations without Visual Studio', "What does calling 'done' do in the context of asynchronous testing?", 'What is the current best solution to clear floats, such as "<div style=\'clear: both\'></div>"?', 'Can I include partial view in Web2Py, passing specific variables into it?', "IONIC - ERROR: resource directory 'C:\\Windows\\System32\\myApp\\platforms\\android\\CordovaLib\\build\\intermediates\\bundles\\debug\\res' does not exist", 'User Username not found in membership store does not exist', 'Adding space between buttons?', "Traceview doesn't work", 'PHP pagination using glob to retrieve images', 'Combining Unique Items From Arrays', 'R: Calculating Pearson correlation and R-squared by group', 'How do I remove from the beginning to the 2nd specific character of a string?', 'How can I install a driver using InnoSetup?', 'Why does 2+\u168040 equal 42?', 'Flat Rate Shipping Based on Order Amount', 'Do you know of any free SOAP webservices (for tutorial purpose)', 'custom font shows on storyboard, but not on simulator, device', 'How to add caption to thumbnail hover - Bootstrap?', 'Environment variable based runtime configuration with sbt native packager', 'CSS Transition Auto Height Without Slowness On Mobile', 'AngularJS showing scientific number in template', 'Meteor JS Iron Router, route sub directory', 'Possible to offload route completion DSL to actors in akka-http?', 'Strange behaviour for recursive enum in Swift (Beta 7)', 'thread-weaver with hibernate unit testing', 'calculate different slopes on the same curve with linear regression?', 'Hardware accelerated video processing tools for Linux', 'SQL Server foreign key constraint - pair (same tuple)', 'How to obtain all the cookies from same domain', 'How to recompile a netbeans project from commandline?', 'Image in inputtext with border in css', 'Table Valued Parameters with Estimated Number of Rows 1', 'Not able to insert into sqlite3 using python', 'How to control the number of downloads via Amazon Cloudfront', 'How to hide the "Data Dictionary" from the Alfresco Repository?', 'Validating across bounded contexts in Domain Driven Design (DDD)?', 'How to call a Javascript Function and make it perform twice properly?', 'Intermingling HTML/CSS/JS landing page with WordPress', 'In Neo4J, how to set the label as a parameter in a cypher query from Java?', "View's transform not changing following device rotation", 'Get value of attribute in an option in HTML', 'Stumped in the middle of a PHP loop', '"download link " fails in IE', 'CSS3 Box shadow to half of the div', 'Integer To Roman Number', 'jQuery: Toggle Dropdown Menu Possibility', 'Weirdness with StackTrace and WCF classes', "How to rename the URL for url: '/add/{id}' to url: '/add' in URL", 'OR condition in the Haskell List comprehensions', 'Karaf Shell : command not found function', 'ActionCable 404 error for wss with ELB and nginx', 'Get the value of the dynamic anchor tag and pass it to the next page', 'embedded relationship hitting server not loading form parent JSON', 'Proxy settings in Firefox don\'t "stick"', 'Erase any duplicate lists in a list. Lisp', 'MySQL / MariaDB shuts down after exactly 1 minute 42 seconds', 'File uploading issue in Yii2', 'Removing specified characters from a string - Efficient methods (time and space complexity)', 'XmlAttributeAttribute type in generated XML file', 'Find the sum of  ...
# ['In RCP Eclipse(Neon) Development, how to enable a created perspective', 'How i can create a toolbar for a specific perspective in rcp?', 'Do jquery still functions same with additional dom element via ajax as already displayed dom element?', 'Determine when app comes out of idle mode in Android M', 'SVN externals repo "is already locked" on update', 'parallely execution of perl language', 'WPF Databinding and Styling based on Data in an item in an IList', 'Is there a way in HBase to COUNT rows matching rowkey-search', 'What triggers Grails HTTP status-based exception mapping?', 'How to seed mysql database by running sql scripts in Ruby Rails platform?', 'Index match where any lookup values are in lookup array', 'bash read strings and output as one key and multiple values', 'Android send byte array with image using Retrofit2', 'Swift - Adding long press gesture recognizer in custom cell', 'Type image not found error in Xamarin.Forms', 'ngGrid cell value is an enum value, how do I use the enum name?', 'Why does my FacesContext.getCurrentInstance().getExternalContext().getUserPrincipal() code runs to NullPointer?', "How to specify network interface with Ruby's Faraday?", 'How to set android:orientation="horizontal" programmatically in RelativeLayout?', 'Sinatra app has session issues in production', 'Spark reading python3 pickle as input', "Counting occurrence of 'every' number in array", 'Strategies for dealing with constantly changing requirements for MySQL schemas?', 'Share on Facebook from the App', 'Cron job scheduling', 'Creating CustomViews as a modular & reusable component which can be used across projects', 'Taking a while for website to return 500 Internal server error', 'Is there any module which allows cropping an image dynamically in Appcelerator for iOS platform?', 'Fast in time Java int[] compression tool', 'getting values out of XML using LINQ to XML', 'How can I get an h1 element to display over an image?', 'Autotools include path', "Turn basic wordpress search into wp-ecommerce search allowing 'product tag search'", 'Dojo + Highcharts: showAxes property moves the x and y axis', 'SVNKit use of auth folder', 'How modulus works with negative numbers in R?', 'Django accepting GET parameters', 'What is a real-world application for HORN?', 'XQuery order by ascending and descending', 'Android change Camera sound', 'How to make APK that can launch my Robotium test?', 'Plotting ROC curve - too many indices error', 'jQuery validationengine IE7 issue', 'Porting a standalone JMS application to a web/app server', 'Convert full line in KML layer to dotted line using javascript', 'iuPHP download external images to User Computer', 'Rails 3 I18n for database tables', 'enable disable jquery ui button with ajax', "rJava won't install on openSUSE 13.2", 'Custom validation on RequestHeader Spring Boot', 'CSS Transition Auto Height Without Slowness On Mobile', 'Testing Angular2 components with transitive dependencies', 'Gitlab-ci running build then hand over to test on separate machine', 'Undefined Property: Security::$table', 'Discover SQL Server procedure default parameters using SYS or INFORMATION_SCHEMA tables', 'Send JSON data between two android or Ipad devices offline (bluetooth) Ionic Cordova Plugin', 'Ajax call to wcf windows service over ssl (https)', 'Linux printing in java', 'Array almost unique criteria', 'Cannot open .sqlproj because it is not supported', 'ReactiveUI How to add condition using WhenAny?', 'SQLite column aliasing', 'rails 3 protect_from_forgery not doing anything', 'Generating public and private key pairs in c# and saving public key as plain text', 'Get None from a Fields data in instead of an empty string', '"Hello World" SOAP Web Service using Spring MVC', 'how to track in gridview whether filter is applied or not in extjs?', 'AS3: Would this cause a memory leak?', 'Excel VBA Syntax Errors & Compiling Issues', "JQUERY, scrollTo, after scrolling down, the page won't let me scroll up for a second... Y?" ...
# ['c multipart form data returning bad request from server', 'HTTP POST mutli part "BAD REQUEST"', 'Multiline REGEX using VB Script', "Python -- switched from Threading to Multiprocessing, now publish/subscribe (Louie) doesn't work", 'usage of observableCollection in longlistselector', 'Proper User and Notifications for Workflow de/activation', 'Oracle - delete all child records for a parent', 'C++ word unscrambler', 'semantic ui grid - display full width of column, after "computer only" columns is hidden', 'Flex: NetStatusEvent not fired by Local Shared Object. Why?', 'How to use a calculated column in same query to calculate another column and so on.. in Hive?', "What's a fast way to parse a math operator off of a string of numbers?", 'Is it possible to have a lazy version of `sequence` without using `unsafeIO`s?', 'Page view in Container not showing content', "AS3 I don't understand the different treatment of an extended movieclip class vs extended simplebutton class", 'preg_match to Javascript function', 'Android bug? WebView FASLE -> FALSE in LogCat', 'Using a function to handle AJAX errors, how can I pass additional parameters?', 'Pause & resume video capture using AVCaptureMovieFileOutput and AVCaptureVideoDataOutput in iOS', 'What is the scope of finalizer thread - per application domain or per process?', 'HTTP Error 500.19 - Internal Server Error', 'How to make a model callback conditional based upon controller actions [:create, :update]?', 'How to create a dynamic destination with BlazeDS', 'Case Syntax Errors', "Lines aren't drawing exactly where I clicked?", 'Docker compose - secrets Additional property secrets is not allowed', 'Odbc_fdw.control is missing', 'Storage::move giving "File not found at path:" Laravel with Ubuntu', 'Cannot build SBT project with IntelliJ IDEA', 'Search posts based on multiple categories WordPress', 'How to rewrite this Capistrano 2 code to use Capistrano 3 syntax? (Rails)', 'Persist js user controls state', 'Initializing record default values in a Current event', 'Time Duration Measure using Dimensions in SSAS', 'AngularJS IE 8 Support', 'Can I query the current scope(s)?', 'Creating X amount of threads that execute a task at the same time', 'Problem disconnecting OpenVpn from application', 'Android Fragments - Multiple tabs/pageflows, custom backstack', 'How to run node.js ES6 file on mac', 'how to parse multiple strings into a string variable using a loop python', 'Read input from redirected stdin with python', 'Finding string values in a Char Array', 'WCF-Service: Return only part of a big object as JSON without creating a new class or contract', 'Put generated items into lists', 'How to display Google maps in a view of an Eclipse RCP application', 'Removing multiple elements with removeUI / wrapping multiple elements with tags$div() assigning an id for each variable', 'knitr refer to a figures with a link', 'Classic ASP Method Not Working When Moved From Win2003 To Win2008 IIS7?', 'Xna folder content missing', 'Ampersands (&) in xlink:href attributes of SVG images?', 'chart.js not displayed in angular2 (rc1)', 'How best to access current_user devise helper in backbone', 'Simple URL mapping issue', 'how to stop running programs on windows 7 with batch commands', 'How to use uwsgi when its built monolithic (with plugins baked in) and installed via dnf on Fedora?', 'Slf4j with Log4j does not print wrapped exception (caused by) when wrapper exception has a message', 'Rotate text in SVG', 'Using ValidateAntiForgeryToken with Ajax.ActionLink', 'elisp Wrong type argument: integer-or-marker-p error', 'What does λ[α =>F] mean?', 'Mahout Plugin for ruby on rails', 'onClick Not Functioning in Chrome in Google Sites', 'Python Requests: .pem -> .crt + key', 'Objective C write to Remote URL', 'Append to a list using indexes stored in another list', 'mongo c driver: how to query documents with "_id" in a list?', 'ios Is it possible to send facebook messages to facebook friends?', 'Hadoop installati ...
# ['Automate code coverage reports for any given week', 'Automated report generation for Crucible Review Coverage Report', 'Loading a table view nib after button push', 'Caching in MVC .NET', 'Do SQL mapping tables speed up queries? How do you use them?', 'Can i setuid for perl script?', 'How do I query a backend layout which is set by parent page?', 'Complex Database Queries in yii2 with Active Record', 'Using NSPredicate with nested arrays ios', 'Beid : C# CryptoAcquireFailed Error=80090019', 'Angular UI-Grid and D3 graph in a row', "Is there a JavaScript (or other) library to read driver's licenses?", 'Group markers for better view on the map', 'Using the vi command to make an alias?', 'Not able to set permission in Android 7.0.0', 'Composition- could someone please clarify?', 'Is there a way to print to the console in an Android app?', 'Need to create li with list of different links using php explode method', 'How to exit a method in the OnEntry method of a PostSharp aspect based on condition', 'Extending TodoMVC to support multiple todo lists', 'Korn-Shell for Windows 7?', 'how to set the fieldname using a template in angularjs', 'ffmpeg conversion .dav to any video files', 'AngularJS 1.3 - Datepicker initial format is incorrect', 'Pass values from an array within a function as params in another function JavaScript', 'What options for convert (ImageMagick or GraphicsMagick) produce the smallest (filesize) PNG?', 'Conditional statements with sql query', 'How do you render multiple partials in a layout multiple times in a view?', 'pass data from javascript to django admin', 'How will i Stop all timers in a form vb.net', 'Why the variable is out of scope?', 'How to render view into string in controller?', 'Using regex in Nodejs stopping flow', 'how to perform $this->render() inside symfony2 service?', "Calling spring data rest repository method doesn't return links", 'Mysterious app crash with OpenGL', "Do Eclipse's Refactoring Tools Violate The Java Language Specification?", 'Save Canvas image on Ipad', 'Jquery-ui tooltip on click', 'Connecting multiple flex clients to a single java class', 'Resource routes exists but Rails throws a 404', 'how to use jquery or ajax to refresh a div at 10 second intervals', 'Shared Object Pool without Thread.Sleep?', 'onClientClick with JavaScript function and eval', 'In Emacs, how do I display a message in the minibuffer with font face properties?', 'simplejson documentation?', 'Xcode 6, Yosemite Mac app help book: topic unavailable', 'how to do linting using nodemon?', 'Is there way to know cmdlet version in Powershell for backward compatibility?', 'Why is the dismissable alert not being dismissed?', 'Update part of page on click with angularjs', 'error: an expression of non-boolean type specified in a context where condition is expected', 'GLSL Shader - Coverflow Reflection of a 2D object', 'Spark: "Truncated the string representation of a plan since it was too large." Warning when using manually created aggregation expression', 'this constructor takes no arguments', 'Android : Find best size for Text based on size of Button', 'Assign Excel Range to a Javascript Array', "Why aren't bound DataGridView cells being updated?", 'How list methods works in java', 'Does an HTML tag exist that is defaulted as an inline-block?', 'Youtube integration in android does not work in Lollipop', 'Restful WCF HTTP Error 404.0 - Not Found when hosting in IIS', 'How do I set Min Date in DateTimepicker from another DateTimepicker?', 'Adding a fontawesome icon with border into form input', 'Rearrange list element - Prolog', 'remove Text selection contextual action bar', "How to get an option element's value by name", 'Remap CTRL-A in command line mode', 'Is UML Class diagrams that great?', "Is there any compare operator in c# like SQL's IN statement", 'Dynamic Topologies vs Fine-grained topologies in Apache Storm', 'Hibernate @OneToMany inside @Embeddable', 'Filter menu based on template-variables input values',  ...
# ['Force MKAnnotationView Callout Bubble to resize when contents change', 'Force redraw of Xamarin.Forms View with custom renderer', 'Python and Django. Remove all js from html', 'Php connect oracle on ARM', 'What does overrideredirect do?', 'WPF Units and Code-Behind', 'Can I host an application in Windows Azure and have the database stored on different server', 'printf ipv6 address using struct in6_addr and ipv4 address using u_int32_t', 'Create button on Firefox toolbar to execute JS', "Neither BindingResult nor plain target object for bean name 'categoryOptions' available as request attribute", 'printing symbols onto an image?', 'Creating a Survey using jQuery - Any examples?', 'Xcode 4.4.1 - C programming - adding new .c files', 'ArgumentError: wrong number of arguments (3 for 1..2) when import .xlsx file extension', 'Getting a fatal error in git for multiple stage entries', 'SQL-92 Query to find earliest date dependent on column value changing', 'Laravel 5.2 Eloquent - how to automatically fetch translated content using separate translations table', 'How to pass access token to Alamofire?', 'ToString and string concatenation - unexpected behavior', 'SQL modify value of columns through addition', 'Hybrid Thread Model (M:N) Implementation', 'How to group by week of the year dates or day dates that start on Sundays in oracle 10?', 'Date function to display the date as mm/dd/yy', 'Makefile include header', 'Ruby on Rails - error when running cucumber: You have already activated activesupport 3.2.1, but your Gemfile requires activesupport 3.1.0.', 'Getting started with JSF - Richfaces on Eclipse', 'How to add values of arrays having different lengths', 'TypeScript: coerce generics T and U', 'How to not overwrite table cell text when adding a control', 'Regex - Select First Match from Javascript Code', 'How to check if a registry key exists', 'Add class to upper li when underlaying input is checked', 'select() on a pipe in blocking mode returns EAGAIN', 'getContextPath using servlet', 'avoid anonymous types in datacontext?', 'How do I use DMProcessConfigXML to provision my Windows Mobile device?', 'Saving and recalling state of elements', 'Select SUM from multiple tables for every record in MySQL table', 'Jquery .get() - How to pass the value of a text box into the data parameter?', 'jaxb bindingx.xml "results in too many target nodes"', 'Enhancing regex to match more URLs', 'Getting Error 503 with UrlFetchApp.fetch', 'Single/sub pixel misalignment of divs on ipad and iphone safari', 'jQuery - Show simple message box when clicked?', 'Python-Sphinx: Link to Section in external File', 'How do I setup my association for Pages that are moveable/can belong to other Journals?', 'MessageDrivenBean instance identifier', 'Jquery datetimepicker in ASP.NET', 'Page Speed Insights - Size Content to Viewport?', 'Retain Checkbox values in Yii gridview pagination', 'Operation between hours', 'NSString sizeWithAttributes: content rect', 'MS Access Multi-Join Query', 'Javascript read from PHP', 'Rendering a screen within a game world in Unity', 'compiling wget with static linking, self compiled (open)ssl library linking issue', 'how does scribefire or deepest sender circumvent same origin policy restriction?', 'Where is the full Yammer API documentation', 'How to show a page where a DIV is with jQuery', 'Real time text box value replace while typing for translator', 'Dynamic matrix with contiguous storage', 'Adding data in the database using microsoft access and OleDb in C#', 'How do I vectorize a boolean operation on a numpy array of datetimes where the boolean operation compares datetime object attributes?', 'How to convert date format for two datetime in bash?', 'Android Google Maps: set boundary on 2 locations and center on one of them', 'Which variable is minimized by scipy.optimize.minimize/How does it work?', 'What is the syntax for a closure argument in swift', "ifstream::read doesn't tell how many bytes it really reads?", 'C++ 11 compat ...
# ['How to return different strings from a Boolean type in MySQL?', 'How to get String value from a boolean value using MySQL query in Jasper Studio', 'ui-select clearing input after selection', 'Perl reading and writing in files', 'git svn clone: Error from SVN, (220001): Item is not readable', 'callback for month, week, day title bar button clicks?', 'How can I use merge to merge two maps/multimaps (C++11 STL)', 'Is there way to know cmdlet version in Powershell for backward compatibility?', 'Cannot get the average date using pandas', 'How to convert user input spaces to dashes', 'Generate a combination of possible words based on specific letter rule substitutions in Java', 'Why does NFS use UDP by default?', 'rest server without pear', 'React-router push callback?', 'Using @PostConstruct annotation in Spring 3.0.0.RC1', 'html emailer shifting changing the position of tables', 'F# NativePtr.stackalloc slower then C# stackalloc - Decompiled Code Included', 'Why Facebook Prepend Comments to their JSONP responses?', 'JS - add timer in mysql as datetime with milliseconds', 'Auto adjust width of divs on show/hide of one div in bootstrap html', 'Apply functions using data from two different lists of data frames', 'Open Source HDR library recommendations', 'group by in Matlab to find the value that resulted minimum similar to SQL', 'MySQL - GROUP BY slow down the page', 'C# search for specific string with specific length', 'enyo.js to integrate with other javascript component', 'Injecting a mock service for an angularjs controller test', 'Generate random data in Oracle based on ranks', 'C#: print array to console line while rounding', 'DOJO form FilteringSelect allow user entered data', 'FileWriter not writing?', 'SQLite Current Timestamp with Milliseconds?', 'Validation condition on friendships in Rails 3?', 'How add a Google Analytics Event to all all <audio> tags, with Javascript?', 'getting classes into the classpath with sbt', 'When to choose development of a PowerShell Module over PowerShell Script', 'Django inspectdb issue using Oracle database', 'Searching/Listing WPF resource files?', 'Change priority headings for a task with the api', 'ASP.net settings', 'Mouseover/hover effect slow on IE8', 'Clear CSS menu hover state on click (page loaded via ajax)', 'Does ESPN Cricinfo have an API?', 'R ifelse() evaluates a condition and returns match', 'Rewrite url to same url but with www', 'Mercurial show diff against 2 parents or base during merge', 'Css :hover for another elements', 'make a pop-up window in php', 'Accessing dimensions of SVG component in Aurelia', 'Plone: Add additional registration fields to users (members)', 'Force weblogic to exclude IncludeTimestamp from generated wsdl', 'Replace numbers with string representation', 'How to handle javax.faces.resource resource not found', 'Express - Promise pending when loop queries', 'Encoding/Escaping JSON Control Characters', 'Install Flash Player plugin on xulrunner 22.0', 'Grails View disappeared in IntelliJ, how to get it back?', 'Generating a KML heatmap from given data set of [lat, lon, density]', 'Railscast Login Remember me', 'Prism EventAggregator subscribe executing twice', 'When is "obj instanceof Object" false in Java?', 'Save Canvas image on Ipad', 'Android Google Maps: set boundary on 2 locations and center on one of them', 'What can be instantiated?', 'DustJS Nested Sections?', 'Install MVC on 2.0.NET Server with IIS6 without Admin Rights', 'SQL convert string(date or text) to date', 'facing issue while parsing xml containing xi:includes with jaxb', 'javax.mail.MessagingException: Could not connect to SMTP host : <host name> port : 25 response: 554', 'BadTokenException - Unable to add window', 'How to run django runserver over TLS 1.2', 'Why DataTable not showing the NULL values?', 'Concatenate two fields', "what's the color of interior of ellipse?", 'C# Load CSV into DataGrid', 'Fragment with swipe-refresh Layout not transitioning', 'Array implementation on FPG ...
# ['Limit message size in logback', 'Text length limit in logback logging', 'Unity // WebGL builds and streamingAssetsPath', 'Moving through the Recordset in Access VBA', 'How can we access payload value in mule EE jdbc-ee query?', 'Track Data Execution Prevention (DEP)', 'Using a single JTextArea with multiple UndoManagers', 'Changing cppcheck alloc/free functions names', 'Is there a tutorial on how to implement Google Authenticator in .NET apps?', 'reorder byte order in hex string (python)', 'HTML and PHP contact form', "I don't understand this Code", 'Twitter Bootstrap tabs, a href with runat server', 'How to prevent SSIS from importing data from a file that already exist in database?', "Python Tkinter application doesn't quit properly", 'Depth map from calibrated image and triangular mesh using OpenCV and Matlab', 'Downloading a auto generated pdf file from controller in mvc3 using c#', 'Hide and show <p> element with javascript', 'How to stop endless EJB 3 timer?', 'How do I express this in Typescript?', 'XML schema for Offfice 2007', 'KML overriding default view after loading', 'How would I organize these calls using Reactive Extensions (Rx) in Silverlight?', 'Can someone explain to me this C++ array?', 'Reading value of android:scheme programatically', 'Entering values to a dialogbox from windows scripting languages like vbs or WSh', 'XStream: Collapsing XML hierarchy as I parse', 'PayPal-iOS-SDK using cocoapods throws error in bridging header', 'Compiler says I am not implementing my interface, but I am?', "Replication Google's Search iOS Cards Animation", 'vagrant - laravel - VBOX_E_FILE_ERROR', 'adding items belongs_to relationship to Active Admin', 'flex datagrid - how to pause or block sorting?', 'Get paid cash amount grouped by day', "Cannot upload file with filename containing open parenthesis char '(' on Microsoft Graph API", "SQL Script 'Find-in-files' Query", 'XPerfView slow to load symbols', 'bootstrap loading wrong grid on mobile', 'Force redraw of Xamarin.Forms View with custom renderer', 'Normalize postal addresses to differentiate dwelling types', 'New unread messages in IMAP not showing up in list', 'make a mysql connection over an alternate port', 'programmatically present and dismiss modal viewController from show navigation stack', 'PHP attachment using SwiftMailer', 'Rails dynamic array to table formatting issue', 'Eclim - What to set org.eclim.java.run.mainclass to?', 'What is #:: method', "Cannot read property 'info' of undefined", 'SimpleCursorAdapter crashing', 'Tycho downloads dependency but fails to resolve it', 'Django sql connection failed', 'php make SOAP Calls in a loop', 'UITableView with UITextField - keep the data even after user scrolls', 'nvd3: set background fill behind line chart', 'Can Flot (or any other JQuery chart library) draw equations?', 'Simple regex in Gruntfile', 'Cross device photo capture for upload', 'How to set attributes as unsafe in RESTful Yii2?', 'javascript / jQuery Press spacebar repeatedly', 'React nested route not mounting', 'What can cause this error on one server, but not another?', 'using background image for li', 'Javascript Return JSON not working', 'How can I modify the JAXB marshalling output stream to include arbitrary inline XML?', 'splitting url causing firefox to bug', 'how do i insert a stack panel into a grid?', 'How to configure Doxygen to document Objective-C categories properly', 'Keystore expire in 5 months later', "Scala's collect inefficient in Spark?", 'Comparing the enum constants in thymeleaf', 'Handling status bar notification before it is displayed', 'empty value of element in IE', 'How to output the intermediate file after gcc has included all header files for a C program?', 'std::exception using message from local object', 'Simple_Form and Bootstrap : input as date how to specify different width for month and year?', 'How to access c++ enum in C file', 'XNA Release becoming unresponsive', 'StructureMap3 How to configure constructor string ...
# ['Limit message size in logback', 'Can a logback message field be truncated/trimmed to n characters?', 'Is it possible to change the reCAPTCHA language in different page?', 'How execute a combination key on node-webkit like c# sendkeys', 'what exactly do stack and mean in context of memory allocation', 'Point Cloud Library and Visual Studio 2010', 'Regex to validate the index of a website vs. a specific page', 'Collect numerals at the beginning of the file', 'How to set a custom UIToolBar always in the front and top of the application?', 'How to grep for URLs in a blog?', "iTunesConnect iOS App with question mark where there should be the app's logo", 'Google Apps Engine PHP Mail API - $image_data', 'Retrieving messages from facebook connector results into 404', 'generating alphanumeric employees id using trigger in mysql?', 'Treat SVG as an image in Silverstripe', 'Generate a list or map of css files', 'Dynamically "Delete" Icon hide show in in kendo scheduler', 'PHP - Issues with infinite looping', 'JavaScript / Show Hide Div > When Radio Button Checked', 'Is it possible to trigger a lambda on creation from CloudFormation template', 'Get UserName value from Login Control', 'Bubble sorting with linked list', 'GridView1.Columns[0].HeaderText = "Text Here" Throws "Index was out of range." Exception', "'no session or session was closed' with JPA 2 and EJB 3.1", "flash javascript don't work (Second try)", 'Speed-optimise a Windows Forms application', 'How do I refer to a list I have given an ID attribute of android:id/list in Java?', 'PowerShell - comparing large fixed width file to large SQL table', 'PivotTable is sorting dates as text, not chronologically', 'Jquery selector variable syntax', 'MySQL Get cumulative customer transactions (not SQL transactions) on a monthly basis', 'Best deployment strategy for local used application in Rails 3.1 on Windows 7?', 'Why is Google Chrome not loading my video?', "TypeError: prc.cng() is not a function in Firefox, Uncaught TypeError: Object #<HTMLInputElement> has no method 'cng' in Chrome", 'predictions from Mclust model object error: \'formal argument "data" matched by multiple actual arguments\'', 'd3.json works but $.getJson fails', 'WCF and What does this mean?', 'Recording/sending screen stream C#', 'Set parameter name as an internal table name', 'jqGrid: pass selected IDs as HTML form parameters', 'How do i find out what is slowing down my page load in IE7', 'C# Math.Round issue with x.95', 'Copying a multi-branch tree to GPU memory', 'Batch that runs a timer in the background. How?', 'WPF and C# Chart mouse events', 'How to run selenium in google app engine/cloud?', 'Two issues with WS_EX_NOACTIVATE and WinForms', 'Android OutOfMemoryError with XML', 'Application Data Folder and Company Name With Underscores', 'Recursive traversal of object', "Can't parse YAML correctly", 'Java - Take text from file and assign matching parameter text to matching object', 'c++ for loop with decrement update causing infinite loop?', 'All Audio frequencies', 'How do you tell Emacs to leave the case alone in a search and replace string?', 'How to create admin panel for yii 1.x framework, also integrate a custom theme such that gii crud auto-generate and auto-integrate css in views?', 'download webpage by asp.net', 'How to assign a rank number to an array when ties exist', 'htaccess mod-rewrite to subdomain', 'Symfony2: local changes for same twig view', 'Finding the modules where changes were checked with svn', 'Why does command substitution change how quoted arguments work?', 'Same JSESSIONID but different Session Object', 'Why is assigning a value to the variable "let" possible?', 'Ransack and namespaced routes... Template missing', 'Unsure of how to approach Data Access Object/Layer in an Express / MongoDB Application', 'error: comparison between a pointer and an integer', "About Android Studio 0.5 'sourceSets'", 'Remote Connection to IIS7 using ServerManager.OpenRemote', 'Access posted json data  ...
# ['Setting a div to be the same height as an image', "Make div's height to be exact as img inside it", 'Information to store in exception object: providing strings in exception', 'Pyglet returns giant error and blank window', 'How to select CBR vs VBR through Android API while recording video in an app', 'Detect the size of a QR Code in Python using OpenCV and Zbar', "while loop isn't working", "jQuery click event doesn't work the second time", "Find current result's position in Mysql", 'Bulk Insert - How to tell SQLServer to insert empty-string and not null', 'LinkedList in Scala', 'OneDrive for Business :"invalid_request","error_description":"AADSTS90014: The request body must contain the following parameter: \'grant_type', 'How to stop gnuplot window poping-up when using it from command line in windows?', "How to configure pybuilder's and pytest's paths right", 'How to decide when use index on table column', 'Programmatically call @Controller', "Best way to construct an ActiveRecord finder using variable AND or OR's?", 'Center form during runtime', 'Spring Boot and JOOQ Auditing Solutions', 'Rails Active record association by instance methods', 'Using jQuery inside iFrame not working', 'Dygraph showing dates in an arbitrary Timezone', 'Ignore exceptions in com.apple.coremedia.networkbuffering', 'C# Reordering List<string> based on another List<string>', 'Does row exist and multiple where', 'Launching an Eclipse 3.x RCP Application using bndtools', 'How can I set the notification in android application to update next version', 'Changing the ObjectContext of an existing IQueryable<>', 'Add radio button on cell in uitableview', 'Why does gcov report in-class function definitions as not executable?', 'WordML Schema generation', 'spring project with multiple issues when executed', 'Could ROWLEX be used as .DLL files in commercial projects (because of some non-LGPL components)?', 'WordPress POST request returns entire HTML page instead of JSON response', 'array as function param', 'How to have a generic.xaml for Silverlight 3 and Silverlight 4?', 'IDL for JSON REST/RPC interface', 'Swagger parameter error "is not exactly one from <#/definitions/parameter>"?', 'GUI for bare git repo', 'Facebook page tab iframe app not working', 'iOS 7: modal view controller status bar is wrong color but normal view controllers are correct', 'Using iTextSharp to generate multiple page PDF from existing PDF Form', 'Only one or many functions per file in PHP?', 'How to Write a Function for WebElement Click in Selenium Webdriver', 'Access inner variables from external functions in javascript', 'Weirdness with StackTrace and WCF classes', 'Draw hollow circle divided into equal parts', "Can't install mongodb dependencies for nodejs (windows)", 'Android load resized image from asset', 'Replacing an equation and embedding a math function plotter?', 'Using Python to calculate sum in CSV row', 'Make a row in a table unique', 'Fluent NHibernate Exception: An association from the table X refers to an unmapped class: System.String', 'Can you get the previous history state object in js?', 'Opencart multistore "domain.com/aaa" instead of "aaa.domain.com"', 'Typescript 1.0 map files do not load', 'How to test method retry on optimistic locking without getting an inifite loop?', 'How to get width of element with javascript?', 'How redirect all page extensions to custom 404 not found page in an asp.net project?', 'How to create relation between nodes grouped under labels in neo4j?', 'How can i pass a value to constructors of collection of instances at runtime with simple injector?', 'What should I put in the "Supporting Files" folder of XCode?', 'SharedElement and custom EnterTransition causes memory leak', 'Advanced Java topics for a C# programmer', 'Image Capture with OpenCV - Select Timeout Error', 'Importing Eclipse project on IntelliJ results in a package error', 'How to get hhh:mm datetime format with Python?', 'How to auto-scroll a gtk.scrolledwindow?', "How  ...
# ...
# ['loop, bug in validation [Python]', 'Validation loop error', 'How to setup delegate/callback from DLL (interop between C and C#)', 'Check PageRank Through XML', 'Could not load file/assembly : Environment : asp.net (vb) visual studio 2005', 'How to create video with images and different time interval?', 'iMessage Sticker App Grid Sticker Sizing', 'Empty email field of Firebase Auth User using Facebook Login Integration (Firebase 3.0)', 'displaying list of choices in a page using play framework', 'My modal window is not transferring values to vb.net codebehind', 'How to generate google-services.json for existing Google Android project?', 'Dependency configurations', 'Azure CosmosDB using Mongo Drivers: Get Count With out getting all documents based on element in sub sub document in C#.Net', 'Amazon SNS configuration for Topics for iPhone/APNs integration', 'FOSUserBundle not found in appkernel', 'How to send personal message to my Facebook friends in iOS SDK', 'jquery ui drag element without keeping mouse button down (follow the cursor)', "Word anagrammer with sql's %", 'CheckedTextViews will randomly appear checked in a list if I click one further up the list', "Getting 'ErrorMissingEmailAddress' error when using Outlook Calendar REST API", 'Unity // WebGL builds and streamingAssetsPath', 'How to add image dynamically?', 'How do I generate static html server-side?', 'Java program output - concurrent', 'How to specify which start event should be called from a BPMN callActivity', "Property 'x' does not exist on type 'never'", 'Web Parts custom property not showing up', 'How to determine if a text has balanced delimiters?', 'How to give title to WPF pages', 'Delphi RTTI SetValue for Enumerations', 'Unique constraint, how to avoid duplicates', 'Different behaviour with std::unordered_map container on Windows and Linux', 'MYSQL joining 3 tables with left join', 'Lauch iOS app from TestFlight is crashing', 'Toast notification every 15 seconds', 'Python: Modifying text file after certain character', 'RegEx to replace text between dollar signs', 'Restricting a user to enter more than 7 digits before decimel and 3 after decimel', 'How do I play a video through .net in windows 7', 'INSERT multiple records in MySQL with one PHP form', 'Web API OData ignore properties added by client-side', 'Autotools include path', 'How do I Display Code Samples On Web Pages With Nice Syntax Styling Like Stack Overflow Does?', 'Scan directory for text files and insert text file data into mysql', 'matching form input to mysql database value', 'Why is Padrino trying to use a template when rendering a json response?', 'Querying an Oracle Date field using a string in NHibernate HQL', 'Does the pricing on high compute queries differ from high byte queries?', 'Parse: Cloud Code Variable Declartaion', 'is it possible to use ORDER BY column not in the GROUP BY?', 'Do i need a running website over internet in order to access Google analytics Data using Google API', "How to display ScheduleState and Blocked columns in custom Grid the way Rally's grid does", 'Xamarin portable library - how to share classes', 'javascript replace() not replacing text containing literal \\r\\n strings', "Can't use Facebook Account Kit: Error inflating class com.facebook.accountkit.ui.ConstrainedLinearLayout", 'UISlider to adjust to match UITextField Value', 'Make jest path more elegant', 'C++ not catching exception, causing python to terminate', 'Conditional image resizing with Carrierwave', 'TVOS 10 SpriteKit Focus Navigation default focused item', 'Why does `datetime.strptime` get an incorrect date for Tuesday in the week 0 of 2015?', 'Eclipse RCP e4 + Tycho Maven + separate Target Platform', "Multiple Task.Factory's", 'Can I change the background color of the primary tile in WinRT?', 'IdentityServer3 - redirect to ADFS if client is on intranet', 'VBScript for creating a scheduled task', 'XML File Creation in Perl - Updated Requirements', 'Reading standard output from process, alwa ...
# ['Parsing this kind of data', 'How to retrieve data from this nested array?', 'C# How to Get Output from CMD (Command = "Defrag c: /U") Before Proccess Ends.', 'Call to avformat_find_stream_info prevents decoding of simple PNG image?', "Dynamic sitemap from database doesn't display the nodes", 'Object Oriented Database Vs object Relational Database', 'How do you detect DOCTYPE (Transitional or Strict) server-side in ASP.NET?', 'Cannot Sync to Github, previous user still holds sync functionality', 'Updating the List UI with Timer', 'Use domain group for ACL C#', 'Using existing Eloquent models (and possibly other Laravel4 features) in CLI scripts?', 'Django Make Migration Error No Such Column', 'A B-Tree - How do I know when the depth of it changes with removal of keys', "jquery popup window won't close on keypress", 'Excel: automatic line color according to entry', 'MYSQL: Can you pull results that match like 3 out of 4 expressions?', 'Use values from a sql query in batch script', 'cakephp auth session regeneration', 'How do I print out a comma multiple times using Boost Preprocessor', 'Speeding up the processing of large data frames in R', 'Binding an attached property to an item in ItemsControl with custom panel problem', 'how to replace overflows with NULL?', 'Read Dynamically created child with rules imposed in Firebase', 'mysql-connector-java driver not found when upgrading past 5.1.39', 'How to kill a java thread using VisualVM or using a unix command?', 'Android SDK installation (adt-bundle-windows-x86_64-20131030)', 'Autofac - How to get class name while creating instance', 'asp Membership updating wrong tables', 'C# vs Fast report error', 'Representing a couple of RDF-triples using tensor. How to programming this modeling process using Python?', 'performing function with classes of similar type C++', 'MonoGame templates in Visual Studio 2015', 'convert multiple records to multiple columns', 'embedding python error on initialization', 'XMLHttpRequest status 0 on second load', 'Getting detected data from the UITextView', "How can i add a new Function or Property on textbox class's text property", 'google maps custom local search / search control', 'git add of unstaged file succeeds, but file is not staged', 'RegDeleteKey and RegDeleteKeyEx', 'Save icon: Still a floppy disk?', 'Unsure on converting strings to double', 'Can TFS workspaces be used without being tied to a specific machine?', 'Set difference: find distinct members for two groups in Tableau Desktop', 'How to convert mysql table to html table to match columns and rows?', 'Get an attribute of a dom node', 'Android / Huawei: java.io.FileNotFoundException: /data/cust/xml/hw_launcher_load_icon.xml: open failed: ENOENT (No such file or directory)', 'Azure - Visual Studio has insufficient privileges to debug this process. To debug this process, Visual Studio must be run as an administrator', 'MySql Linked Server from MSSQL server?', 'calling some logic before user is logged out using spring security?', 'Game conversion from AS2 to AS3', 'Fastest way to transfer a file over UDP', 'Help Writing an Asynchronous Unit Test In Silverlight', 'Replace words of text area', 'How to download a file to server PHP?', 'Scala variable binding when used with Actors', 'xsltProcessor.importStylesheet error', 'Dynamic list and blank space filtering', 'Convert List<Object[]> to JSON', 'Line-oriented streams in Node.js', 'specify the working directory for msbuild', 'Makefile on GCC for C', 'Adding in-app purchase to existing published application and testing it without publishing', 'Subversion with Continuous Integration', 'UIWebView - Add an extra parameter to the url request', 'ExtJS4 LinkButton Component', 'MySQL, Highcharts: "operand should contain 1 column(s):" error', 'Which editor can align tables in reStructuredText for Sphinx?', "Xamarin method 'CGSize..ctor' not found", 'How to add a peridic timer callback in a linux kernel module', 'Only the home button works in my apps', 'PH ...
# ['ios Is it possible to send facebook messages to facebook friends?', 'How to send personal message to my Facebook friends in iOS SDK', 'Vertically stack an array of buttons using auto layout VFL', 'Make element behave same after css scaling', 'Parameters to Script', "Why I'm getting 'Non-static method should not be called statically' when invoking a method in a Eloquent model?", "Are there any reasons why h2 database shouldn't be used in production?", 'What is the best way to get contents from a div?', 'Lucene StopFilter and PorterStemmer not found', 'How to use group', 'How compiler like GCC implement acquire/release semantics for std::mutex', 'Using twitter login in ios', 'ExtJS floating window focus lose detection', 'C# Test if the actual time is inside a TimeSpan?', 'Android, difference between level and RSSI of a wifi signal?', 'How to set: Windows 7 - COM Port - Baud Rate to 921600', 'PLSQL procedure execution error invalid statement', 'How to convert .csv to .mdb (MS Access) format', 'MVVM multiple selection, keep after data reloading', 'Loading XML based on attribute value', 'How can I default to IE for testing my ASP.NET application?', 'Trouble creating KeyDown event in Panel', 'Why does bloodhound.get() return undefined?', 'CodeIgniter compatibility with PHP version?', 'How to create folder for generated sources in Maven?', "Python's hasattr on list values of dictionaries always returns false?", 'Is there a way to tell if an object has implemented ToString explicitly in c#', 'Using php to send form to my email..Having an issue with 405 Not Allowed when form is submitted', 'Google Geocharts: Regions and Markers on same map?', 'Stop a running AppleScript in such a way that calls its error handler', 'How to find files with same size (possible duplicates) in a directory and its subfolders in Linux?', 'Preventing deadlock in "INSERT IF NOT EXISTS" in SSIS', 'XSLT takes escape sequences as parameter', 'In Python, is time.time() * 1000 precise enough?', 'MapReduce using MongoDB Java Driver failes with wrong type for BSONElement assertion', 'Enumerate system drives in nodejs', 'How can I show the same HTML 5 Video twice on a website without loading it twice?', 'Why does Twitter use -9999px instead of 0 for top/bottom values of their hero images?', 'How to close jquery lighbox popup without clicking close option at top', 'JavaFx ONLY TOP innerShadow', 'How to take heap dump in Sun JDK 1.5 (windows) programmatically', 'GlassFish 3 Authentication Failed', 'get values from ruby array if condition', 'How can I display a Microsoft SQL Server Reporting Services Report in an iPad App?', 'How to type characters in an interval?', "Inner div aren't pushing other div, cant get clear: both; to work", 'Number at f(93) in fibonacci series has negative value, how?', 'Save multiple results from AWK to shell variables', 'Google Maps - make ZoomControl large', 'Repeatable way to remove a row from a data frame that ends in a certain character', 'How to wait for multiple input changes on child components?', 'Biqquery quota limits on UDF', 'font size scaling in Windows Store Universal App (W8.1 + WP8.1)', 'stop playing automatically video in UIWebView in ios', 'How to interpret NetworkReachabilityFlags in Xamarin.iOS?', 'What does $$@ and the pipe symbol in Makefile stand for?', 'To Add Header and Footer for many word documents?', 'Postgres Strings comparison peculiarity', 'Java Neo4j Cypher query results in unsupportedException when node(*) is used vice node(1,2,3...)', 'Apple Push Notification Service connects, but no notification is recieved', 'Call aspnet_regsql.exe from SQL script', 'app.config custom section reading', 'Change class of other div when hovering on one div', 'Akka: can I avoid serialization for local messages?', 'Select Cascade Using jQuery and PHP in Laravel 4', 'Nesuite PHP Custom Record', 'MediaWiki - how do I create a page which auto populates a link from the current page?', 'Is it possible to squash two pushed commits fro ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-0898de55c095> in <module>()
#       1 for line in validation:
# ----> 2   print(line)
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/iostream.py in write(self, string)
#     398             is_child = (not self._is_master_process())
#     399             # only touch the buffer in the IO thread to avoid races
# --> 400             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     401             if is_child:
#     402                 # newlines imply flush in subprocesses
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     414                                  copy_threshold=self.copy_threshold)
#     415             data.group = group
# --> 416         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     417
#     418     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.6/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
for line in prepared_validation:
  print(l for l in line)

# %% [markdown]
# Let's evaluate the approach again after the preparation:

# %%
wv_prepared_ranking = []
for line in prepared_validation:
    q, *ex = line
    ranks = rank_candidates(q, ex, wv_embeddings)
    wv_prepared_ranking.append([r[0] for r in ranks].index(0) + 1)

# %%
for k in [1, 5, 10, 100, 500, 1000]:
    print("DCG@%4d: %.3f | Hits@%4d: %.3f" % (k, dcg_score(wv_prepared_ranking, k), 
                                              k, hits_count(wv_prepared_ranking, k)))
# Out:
# DCG@   1: 0.306 | Hits@   1: 0.306
# DCG@   5: 0.379 | Hits@   5: 0.444
# DCG@  10: 0.396 | Hits@  10: 0.496
# DCG@ 100: 0.430 | Hits@ 100: 0.665
# DCG@ 500: 0.453 | Hits@ 500: 0.841
# DCG@1000: 0.469 | Hits@1000: 1.000

# %% [markdown]
# Now, prepare also train and test data, because you will need it in the future:

# %%
def prepare_file(in_, out_):
    out = open(out_, 'w')
    for line in open(in_, encoding='utf8'):
        line = line.strip().split('\t')
        new_line = [text_prepare(q) for q in line]
        print(*new_line, sep='\t', file=out)
    out.close()

# %%
prepare_file('data/train.tsv', 'data/train-prepared.tsv')
prepare_file('data/validation.tsv', 'data/validation-prepared.tsv')
prepare_file('data/test.tsv', 'data/test-prepared.tsv')

# %% [markdown]
#  For each question from prepared *test.tsv* submit the ranks of the candidates to earn the points. The calculations should take about 3-5 minutes. Pay attention that the function *rank_candidates* returns a ranking, while in this case you should find a position in this ranking. Ranks should start with 1.

# %% [markdown]
# ## Advanced solution: StarSpace embeddings
#
# Now you are ready to train your own word embeddings! In particular, you need to train embeddings specially for our task of duplicates detection. Unfortunately, StarSpace cannot be run on Windows and we recommend to use provided
# [docker container](https://github.com/hse-aml/natural-language-processing/blob/master/Docker-tutorial.md) or other alternatives. Don't delete results of this task because you will need it in the final project.
#
# ### How it works and what's the main difference with word2vec?
# The main point in this section is that StarSpace can be trained specifically for some tasks. In contrast to word2vec model, which tries to train similar embeddings for words in similar contexts, StarSpace uses embeddings for the whole sentence (just as a sum of embeddings of words and phrases). Despite the fact that in both cases we get word embeddings as a result of the training, StarSpace embeddings are trained using some supervised data, e.g. a set of similar sentence pairs, and thus they can better suit the task.
#
# In our case, StarSpace should use two types of sentence pairs for training: "positive" and "negative". "Positive" examples are extracted from the train sample (duplicates, high similarity) and the "negative" examples are generated randomly (low similarity assumed).
#
# ### How to choose the best params for the model?
# Normally, you would start with some default choice and then run extensive experiments to compare different strategies. However, we have some recommendations ready for you to save your time:
# - Be careful with choosing the suitable training mode. In this task we want to explore texts similarity which corresponds to *trainMode = 3*.
# - Use adagrad optimization (parameter *adagrad = true*).
# - Set the length of phrase equal to 1 (parameter *ngrams*), because we need embeddings only for words.
# - Don't use a large number of *epochs* (we think that 5 should be enough).
# - Try dimension *dim* equal to 100.
# - To compare embeddings usually *cosine* *similarity* is used.
# - Set *minCount* greater than 1 (for example, 2) if you don't want to get embeddings for extremely rare words.
# - Parameter *verbose = true* could show you the progress of the training process.
# - Set parameter *fileFormat* equals *labelDoc*.
# - Parameter *negSearchLimit* is responsible for a number of negative examples which is used during the training. We think that 10 will be enought for this task.
# - To increase a speed of training we recommend to set *learning rate* to 0.05.

# %% [markdown]
# Train StarSpace embeddings for unigrams on the train dataset. You don't need to change the format of the input data. Just don't forget to use prepared version of the training data.
#
# If you follow the instruction, the training process will take about 1 hour. The size of the embeddings' dictionary should be approximately 100 000 (number of lines in the result file). If you got significantly more than this number, try to check all the instructions above.

# %%
# %%bash
# ./Starspace/starspace train \
# -trainFile data/train-prepared.tsv \
# -model Starspace_embeddings \
# -trainMode 3 \
# -adagrad true \
# -ngrams 1 \
# -epoch 5 \
# -dim 100 \
# -similarity "cosine" \
# -minCount 2 \
# -verbose true \
# -fileFormat labelDoc \
# -negSearchLimit 10 \
# -lr 0.05 \
# -thread 10

# %% [markdown]
# And now we can compare the new embeddings with the previous ones. You can find trained word vectors in the file *[model_file_name].tsv*. Upload the embeddings from StarSpace into a dict.

# %%
import csv
with open('Starspace_embeddings.tsv', newline='') as embedding_file:
    reader = csv.reader(embedding_file, delimiter='\t')
    embedding_file_lines = list(reader)
    
starspace_embeddings = {}
for line in embedding_file_lines:
    word = line[0]
    embedding = np.array(line[1:]).astype(np.float32)
    starspace_embeddings[word] = embedding

# %%
prepared_validation = read_corpus("data/validation-prepared.tsv")

# %%
ss_prepared_ranking = []
for line in prepared_validation:
    q, *ex = line
    ranks = rank_candidates(q, ex, starspace_embeddings, 100)
    ss_prepared_ranking.append([r[0] for r in ranks].index(0) + 1)

# %%
for k in [1, 5, 10, 100, 500, 1000]:
    print("DCG@%4d: %.3f | Hits@%4d: %.3f" % (k, dcg_score(ss_prepared_ranking, k), 
                                               k, hits_count(ss_prepared_ranking, k)))

# %%
for line in prepared_validation[:100]:
    q, *ex = line
    ranks = rank_candidates(q, ex, starspace_embeddings, 100)
    print("Question:")
    print(q)
    print("top 6 Duplicate Ranking:")
    for rank in ranks[:6]:
      print(rank[1])
    print("\n\n\n\n")

# %% [markdown]
# Due to training for the particular task with the supervised data, you should expect to obtain a higher quality than for the previous approach. In additiion, despite the fact that StarSpace's trained vectors have a smaller dimension than word2vec's, it provides better results in this task.
